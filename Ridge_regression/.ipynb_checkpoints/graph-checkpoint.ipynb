# %%
from sklearn.datasets import make_regression
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
x,y = make_regression(n_samples = 100, n_features = 1, n_informative=1, n_targets=1, noise=20,random_state=1)

# %%
x.shape,y.shape
# Out:
# ((100, 1), (100,))

# %%
plt.scatter(x,y)

# %%
X_train,X_test,Y_train,Y_test = train_test_split(x,y,test_size=0.2,random_state=1)

# %%
lr = LinearRegression()
lr.fit(X_train,Y_train)

lr.coef_,lr.intercept_
# Out:
# (array([81.97561116]), np.float64(4.282288483160598))

# %%
def cal_loss(m,alpha):
    return np.sum(y - m*x.ravel() + 4.282288)**2 + alpha*m*m

# %%
import numpy as np
m = np.linspace(-200,200,100)
plt.figure(figsize=(4,6))
for i in [0,5,10,20,30,100]:
    loss = []
    for j in range(m.shape[0]):
        loss_i = cal_loss(m[j],i)
        loss.append(loss_i)
    plt.plot(m,loss,label = f"alpha={i}")
plt.legend()
plt.xlabel("m")
plt.ylabel("loss")
plt.show()
